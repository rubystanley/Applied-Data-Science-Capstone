# %% [markdown]
# <a href="https://colab.research.google.com/github/rubystanley/Applied-Data-Science-Capstone/blob/main/Edmonton_Income_distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Capstone Project - The Battle of the Neighborhoods (Week 4)
# # Applied Data Science Capstone by IBM/Coursera

# %% [markdown]
# # Table of contents
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# # Introduction : Business Problem
#
# Understanding your target market is undoubtedly one of the most important steps for any new or aspiring entrepreneur. Various demographic factors such as age , gender , race ,income etc  play an important role in customer segmentation. Among them ,a customer's income gives a good measure the buying power of your audience.When you know the income range of consumers in a neighbourhood,  you can design appropriate marketing strategies and find matching products for this population.
#
# This projects aims to find the analyze neighbourhoods in Edmonton,Alberta based on their income category and then predict the most preferred neighbourhood for starting a particular category of business .We also use Foursquare API and other data science tools to analyse these the wealthy boroughs and find out the common venues in these neighbourhoods.The first part of the project aims to find the borough with high income neighbourhoods in Edmonton. We will then use k-means clustering to segment the neighbourhoods in these boroughs and try to predict what would be the best category of business to start in any affluent neighbourhood.

# %% [markdown]
# #Data

# %% [markdown]
# We have used the dataset that is  publicly available in the website data.edmonton.ca
#
# ### 1. Edmonton -2016 Census - Population by Household Income (Neighbourhood/Ward)
#  Source : https://data.edmonton.ca/Census/2016-Census-Population-by-Household-Income-Neighbo/jkjx-2hix
#
# #### Columns in this dataset and datatype
# 1 City Ward Number- Plain Text
#
# 2.Neighbourhood Number- Number
#
# 3.Neighbourhood Name	-Plain Text
#
# 4.Less than $30,000	-Number
#
# 5.$30,000 to less than 60,000 -Number
#
# 6.$60,000 to less than 100,000	-Number
#
# 7.$100,000 to less than 125,000	-Number
#
# 8.$125,000 to less than 150,000 -Number
#
# 9.$150,000 to less than 200,000-Number
#
# 10.$200,000 to less than 250,000	-Number
#
# 11.$250,000 or more -Number
#
# 12.No Response	-Number

# %% [markdown]
# ### Methodology
# In this project we will focus on analyzing Edmonton which is the capital city of Alberta.
# We will first look at the census data of Edmonton which has provides insights on the income distribution within Edmonton. We will then add the location data of each neighbourhood and add this to the census data.
#
# In the second part ,using Foursquare API ,we will get details about the common venues within each neighbourhood. For simplicity purposes , we will only analyze the most affluent borough.
#
# Finally we will use k means algorithm to create clusters of neighbourhoods within the most affluent borough to analyze which are the most common categories of business within each neighbourhood.

# %% [markdown]
# ## Importing necessary packages

# %%
import random # library for random number generation
import numpy as np # library for vectorized computation
import pandas as pd # library to process data as dataframes

import matplotlib.pyplot as plt # plotting library
# backend for rendering plots within the browser
# %matplotlib inline 

from sklearn.cluster import KMeans 
from sklearn.datasets.samples_generator import make_blobs


import numpy as np
import pandas as pd

#Command to install OpenCage Geocoder for fetching Lat and Lng of Neighborhood
# !pip install opencage

#Importing OpenCage Geocoder
from opencage.geocoder import OpenCageGeocode

# use the inline backend to generate the plots within the browser
# %matplotlib inline 

#Importing Matplot lib and associated packages to perform Data Visualisation and Exploratory Data Analysis
import matplotlib as mpl
#import matplotlib.pyplot as plt

mpl.style.use('ggplot') # optional: for ggplot-like style

# check for latest version of Matplotlib
print ('Matplotlib version: ', mpl.__version__) # >= 2.0.0

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

#Importing folium to visualise Maps and plot based on Lat and Lng
import folium

#Requests to request web pages by making get requests to FourSquare REST Client
import requests

#To normalise data returned by FourSquare API
from pandas.io.json import json_normalize

# !pip install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

#Importing KMeans from SciKit library to Classify neighborhoods into clusters
from sklearn.cluster import KMeans

print('Libraries imported')




print('Libraries imported.')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.datasets.samples_generator module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.datasets. Anything that cannot be imported from sklearn.datasets is now part of the private API.
#   warnings.warn(message, FutureWarning)
# Collecting opencage
#   Downloading opencage-2.0.0-py3-none-any.whl (13 kB)
# Collecting pyopenssl>=0.15.1
#   Downloading pyOpenSSL-20.0.1-py2.py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 1.7 MB/s
# Collecting backoff>=1.10.0
#   Downloading backoff-1.11.1-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: Requests>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from opencage) (2.23.0)
# Collecting cryptography>=3.2
#   Downloading cryptography-3.4.7-cp36-abi3-manylinux2014_x86_64.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 10.9 MB/s
# Requirement already satisfied: six>=1.5.2 in /usr/local/lib/python3.7/dist-packages (from pyopenssl>=0.15.1->opencage) (1.15.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=3.2->pyopenssl>=0.15.1->opencage) (1.14.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=3.2->pyopenssl>=0.15.1->opencage) (2.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from Requests>=2.2.0->opencage) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from Requests>=2.2.0->opencage) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from Requests>=2.2.0->opencage) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from Requests>=2.2.0->opencage) (2021.5.30)
# Installing collected packages: cryptography, pyopenssl, backoff, opencage
# Successfully installed backoff-1.11.1 cryptography-3.4.7 opencage-2.0.0 pyopenssl-20.0.1
# Matplotlib version:  3.2.2
#
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# no such option: --yes
# Libraries imported
# Libraries imported.

# %% [markdown]
# Here we will try to group the people based on their annual household income. We will create 3 groups namely the high income , middle class and the lower income groups

# %% [markdown]
# ### Downloading Data
# Let's download the data and save it as a CSV file called neighborhood_income.csv

# %%
neighborhood_income_df = pd.read_csv('https://raw.githubusercontent.com/rubystanley/Applied-Data-Science-Capstone/main/2016_Census_-_Population_by_Household_Income__Neighbourhood_Ward_.csv',index_col=None)
neighborhood_income_df.head()
# Out:
#      Ward  Neighbourhood Number  ... $250,000 or more  No Response
# 0  WARD 1                  3140  ...              103          404
# 1  WARD 1                  3330  ...               95          577
# 2  WARD 5                  4220  ...               13          882
# 3  WARD 9                  5454  ...               77         1938
# 4  WARD 3                  2461  ...                0            0
#
# [5 rows x 12 columns]

# %% [markdown]
# #### Lets create 3 new columns High Income , Middle class and Lower Income in the dataframe. The columns will contain the total number of people in each category
#
# High Income will be be greater than or equal to $150,000
#
# Middle Class will be 60,000 to 150000
#
# Low Income will be less than 60,000

# %%
neighborhood_income_df['low']=neighborhood_income_df['Less than $30,000']+neighborhood_income_df['$30,000 to less than $60,000']
neighborhood_income_df['middle']=neighborhood_income_df['$60,000 to less than $100,000']+neighborhood_income_df['$100,000 to less than $125,000']+neighborhood_income_df['$125,000 to less than $150,000']
neighborhood_income_df['high']=neighborhood_income_df['$150,000 to less than $200,000']+neighborhood_income_df['$200,000 to less than $250,000']+neighborhood_income_df['$250,000 or more']

# %%
neighborhood_income_df.head()
# Out:
#      Ward  Neighbourhood Number     Neighbourhood Name  ...  low  middle  high
# 0  WARD 1                  3140              CRESTWOOD  ...  147     168   197
# 1  WARD 1                  3330               PARKVIEW  ...  167     307   249
# 2  WARD 5                  4220         JAMIESON PLACE  ...   97     245    95
# 3  WARD 9                  5454             RUTHERFORD  ...  498    1210   449
# 4  WARD 3                  2461  CRYSTALLINA NERA EAST  ...    0       0     0
#
# [5 rows x 15 columns]

# %%
#neighborhood_income_df.drop(['Less than $30,000','$30,000 to less than $60,000','$60,000 to less than $100,000','$100,000 to less than $125,000','$125,000 to less than $150,000','$150,000 to less than $200,000','$200,000 to less than $250,000','$250,000 or more'],axis =1,inplace= True)

# %%
## neighborhood_income_df.drop('No Response',axis=1, inplace=True)

# %%
neighborhood_income_df.head()
# Out:
#      Ward  Neighbourhood Number     Neighbourhood Name  ...  low  middle  high
# 0  WARD 1                  3140              CRESTWOOD  ...  147     168   197
# 1  WARD 1                  3330               PARKVIEW  ...  167     307   249
# 2  WARD 5                  4220         JAMIESON PLACE  ...   97     245    95
# 3  WARD 9                  5454             RUTHERFORD  ...  498    1210   449
# 4  WARD 3                  2461  CRYSTALLINA NERA EAST  ...    0       0     0
#
# [5 rows x 15 columns]

# %%
neighborhood_income_df
# Out:
#         Ward  Neighbourhood Number     Neighbourhood Name  ...  low  middle  high
# 0     WARD 1                  3140              CRESTWOOD  ...  147     168   197
# 1     WARD 1                  3330               PARKVIEW  ...  167     307   249
# 2     WARD 5                  4220         JAMIESON PLACE  ...   97     245    95
# 3     WARD 9                  5454             RUTHERFORD  ...  498    1210   449
# 4     WARD 3                  2461  CRYSTALLINA NERA EAST  ...    0       0     0
# ..       ...                   ...                    ...  ...  ...     ...   ...
# 383   WARD 7                  2040         BEACON HEIGHTS  ...  294     285    33
# 384  WARD 11                  6260      GIRARD INDUSTRIAL  ...    0       0     0
# 385   WARD 2                  3480                 HUDSON  ...  119     258    50
# 386   WARD 7                  2330              HIGHLANDS  ...  209     352   141
# 387   WARD 5                  4467   RIVER VALLEY CAMERON  ...    0       0     0
#
# [388 rows x 15 columns]

# %% [markdown]
# Adding 2 new columns showing the total respondents and total population in each neighborhood

# %%
neighborhood_income_df['total'] = neighborhood_income_df['high']+neighborhood_income_df['low']+neighborhood_income_df['middle']
neighborhood_income_df['Population'] = neighborhood_income_df['high']+neighborhood_income_df['low']+neighborhood_income_df['middle']+neighborhood_income_df['No Response']
neighborhood_income_df.drop('No Response',axis=1, inplace=True)

# %%
neighborhood_income_df.head()
# Out:
#      Ward  Neighbourhood Number     Neighbourhood Name  ...  high  total  Population
# 0  WARD 1                  3140              CRESTWOOD  ...   197    512         916
# 1  WARD 1                  3330               PARKVIEW  ...   249    723        1300
# 2  WARD 5                  4220         JAMIESON PLACE  ...    95    437        1319
# 3  WARD 9                  5454             RUTHERFORD  ...   449   2157        4095
# 4  WARD 3                  2461  CRYSTALLINA NERA EAST  ...     0      0           0
#
# [5 rows x 16 columns]

# %% [markdown]
# ###Next step is to get information about the Boroughs to which the neighbourhoods belong from Wiki
#
# #####I have created a CSV file of Boroughs based on the info available on the page
# https://en.wikipedia.org/wiki/List_of_neighbourhoods_in_Edmonton

# %%
neigh_boro_df = pd.read_csv('https://raw.githubusercontent.com/rubystanley/Applied-Data-Science-Capstone/main/Edmonton_neigh_boro.csv',index_col=None)
print("Total Neighbourhood Count",len(neigh_boro_df['Neighbourhood Name']),"Borough Count",len(neigh_boro_df['Borough'].unique()))
neigh_boro_df.head()
# Out:
# Total Neighbourhood Count 388 Borough Count 9
#       Neighbourhood Name     Borough
# 0              CRESTWOOD        West
# 1               PARKVIEW        West
# 2         JAMIESON PLACE        West
# 3             RUTHERFORD  South West
# 4  CRYSTALLINA NERA EAST  North East

# %% [markdown]
# ### Merging the Census Data Table with the newly created dataframe to include Boroughs

# %%
edm_neigh_inc_boro = pd.merge(neighborhood_income_df,neigh_boro_df, on='Neighbourhood Name')

edm_neigh_inc_boro.head()
# Out:
#      Ward  Neighbourhood Number  ... Population     Borough
# 0  WARD 1                  3140  ...        916        West
# 1  WARD 1                  3330  ...       1300        West
# 2  WARD 5                  4220  ...       1319        West
# 3  WARD 9                  5454  ...       4095  South West
# 4  WARD 3                  2461  ...          0  North East
#
# [5 rows x 17 columns]

# %% [markdown]
# #Exploratory Data Analysis

# %% [markdown]
# #### Largest Borough by the number of neighbourhoods

# %% [markdown]
# Checking out how many neighbourhoods are there in each Borough. South West Borough has the maximum followed by South East.

# %%
edm_neigh_inc_boro.dropna(inplace=True)
edm_neigh_inc_boro['Borough'].value_counts()
# Out:
# South West    74
# South East    71
# West          64
# North East    62
# North West    56
# Central       44
# North         13
# South          3
# East           1
# Name: Borough, dtype: int64

# %% [markdown]
# ### Top 2 High Income Neighbourhoods in each Borough

# %%
# get dataframe sorted by high income in each Borough 
top3 = edm_neigh_inc_boro.groupby(['Borough']).apply(lambda x: x.sort_values(["high"], ascending = False)).reset_index(drop=True)
# select top N rows within each continent
top3.groupby('Borough').head(2)
# Out:
#         Ward  Neighbourhood Number  ... Population     Borough
# 0     WARD 6                  1150  ...      12501     Central
# 1     WARD 6                  1090  ...       8690     Central
# 44    WARD 8                  6380  ...          3        East
# 45    WARD 3                  3080  ...       1027       North
# 46    WARD 4                  2530  ...        862       North
# 58    WARD 4                  2340  ...       2074  North East
# 59    WARD 3                  2440  ...       1861  North East
# 120   WARD 2                  3240  ...       3465  North West
# 121   WARD 6                  3440  ...       3052  North West
# 176   WARD 9                  5466  ...          0       South
# 177   WARD 9                  5463  ...          0       South
# 179  WARD 12                  6213  ...       4491  South East
# 180   WARD 8                  6550  ...       2489  South East
# 250   WARD 9                  5454  ...       4095  South West
# 251   WARD 9                  5511  ...       2238  South West
# 324   WARD 5                  4461  ...       4003        West
# 325   WARD 1                  3330  ...       1300        West
#
# [17 rows x 17 columns]

# %% [markdown]
# Dropping the column WARD since these are not going to be used for the analysis

# %%
#edm_neigh_inc_boro.drop('Ward',axis=1,inplace=True)
#edm_neigh_inc_boro.drop('Neighbourhood Number',axis=1,inplace=True)
edm_neigh_inc_boro.head()
edm_neigh_inc_boro.groupby('Borough').sum()
# Out:
#             Neighbourhood Number  Less than $30,000  ...  total  Population
# Borough                                              ...
# Central                   164336               8824  ...  33070       67614
# East                        6380                  0  ...      0           3
# North                      37606                482  ...   2803        6012
# North East                166439               4840  ...  29407       56350
# North West                200545               3423  ...  22245       45231
# South                      17439                  0  ...      0           0
# South East                453788               4396  ...  33812       66604
# South West                386535               4677  ...  38443       75598
# West                      268264               3266  ...  26078       52214
#
# [9 rows x 14 columns]

# %% [markdown]
# ### Adding the latitude and longitude data to the dataframe.
# Latitude and longitude data of the neighbourhoods have been obtained from the dataset available on https://data.edmonton.ca/City-Administration/City-of-Edmonton-Neighbourhoods-Centroid-Point-/3b6m-fezs/data

# %%
locgeo_df = pd.read_csv('https://raw.githubusercontent.com/rubystanley/Applied-Data-Science-Capstone/main/City_of_Edmonton_-_Neighbourhoods__Centroid_Point_.csv', index_col=None)
locgeo_df.head()
edm_data =pd.merge(edm_neigh_inc_boro,locgeo_df, on='Neighbourhood Number')
#edm_data.drop(['Ward'],axis=1)
#edm_data.drop('Geometry Point',axis=1)
edm_data.drop(['Ward','Geometry Point','Neighbourhood Name_y'],axis = 1,inplace = True)
edm_data.rename(columns = {'Neighbourhood Name_x':'Neighbourhood Name'}, inplace = True)
edm_data.rename(columns = {'low':'Low Income'}, inplace = True)
edm_data.rename(columns = {'middle':'Middle Class'}, inplace = True)
edm_data.rename(columns = {'high':'High Income'}, inplace = True)
edm_data.rename(columns = {'total':'Total Respondents'}, inplace = True)
edm_data
# Out:
#      Neighbourhood Number  ...                                   Location
# 0                    3140  ...   (53.53543354829023, -113.56903784940349)
# 1                    3330  ...  (53.524060365765735, -113.56791414354251)
# 2                    4220  ...   (53.48870738352453, -113.64901968042588)
# 3                    5454  ...   (53.416764847830855, -113.5297880243958)
# 4                    6470  ...  (53.455341806482764, -113.45724258627415)
# ..                    ...  ...                                        ...
# 376                  2040  ...   (53.57353937720545, -113.40604010233069)
# 377                  6260  ...    (53.5111698547205, -113.43772379533199)
# 378                  3480  ...   (53.60458741126075, -113.55339575677799)
# 379                  2330  ...    (53.5659985899366, -113.43017053031933)
# 380                  4467  ...   (53.47235679378515, -113.61607674195818)
#
# [381 rows x 20 columns]

# %% [markdown]
# Grouping the dataframes by Boroughs ,it can be seen that the South West Borough has a large number of High Income population followed by the West and South East. Another  observation is that the Central zone has a large number of people in the lower income category , so maybe this sector is not a good location to start a luxury business

# %%
edm_data.groupby('Borough').sum()
# Out:
#             Neighbourhood Number  Less than $30,000  ...     Latitude    Longitude
# Borough                                              ...
# Central                   157605               8824  ...  2302.038665 -4880.525151
# East                        6380                  0  ...    53.522269  -113.413848
# North                      37606                482  ...   696.704138 -1475.466253
# North East                163978               4840  ...  3269.538984 -6918.377457
# North West                196075               3423  ...  2947.463510 -6246.100342
# South                      17439                  0  ...   160.272673  -340.494705
# South East                440688               4389  ...  3690.004195 -7826.792716
# South West                380958               4671  ...  3902.373462 -8289.886930
# West                      267154               3266  ...  3372.368047 -7158.230062
#
# [9 rows x 17 columns]

# %% [markdown]
# ##Creating a map of Edmonton using Folium

# %% [markdown]
# #### Use geopy library to get the latitude and longitude values of Edmonton

# %%
address = 'Edmonton'
geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinates of Edmonton are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinates of Edmonton are 53.535411, -113.507996.

# %%
# create map of Edmonton using latitude and longitude values
map_edm = folium.Map(location=[latitude, longitude], zoom_start=10)
map_edm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_056d961266a843a584453e84f3e918e4%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_056d961266a843a584453e84f3e918e4%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_056d961266a843a584453e84f3e918e4%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_056d961266a843a584453e84f3e918e4%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B53.535411%2C%20-113.507996%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_673bd345023d409d871b3b756756cb83%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20%2 ...

# %% [markdown]
# ####Create a map of Edmonton with neighborhoods and population superimposed on top.

# %%
# add markers to map
for lat, lng, borough, neighborhood,population in zip(edm_data['Latitude'], edm_data['Longitude'], edm_data['Borough'], edm_data['Neighbourhood Name'],edm_data['Population']):
    #label = '{}, {}'.format(neighborhood, borough)
    label = '{}, {}'.format(neighborhood, population)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_edm)  
    
map_edm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_056d961266a843a584453e84f3e918e4%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_056d961266a843a584453e84f3e918e4%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_056d961266a843a584453e84f3e918e4%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_056d961266a843a584453e84f3e918e4%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B53.535411%2C%20-113.507996%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_673bd345023d409d871b3b756756cb83%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20%2 ...

# %% [markdown]
# ### Analyzing the most affluent borough which is the South West borough

# %% [markdown]
# Since South west Borough has the largest population of affluent class , it is best to choose this location to start any luxury business. Let's create a dataset with only neighbourhoods in South West for the purpose of analyzing this neighbourhood further

# %%
edm_swest = edm_data

edm_swest = edm_swest[edm_swest['Borough'] == 'South West']
edm_swest.reset_index(inplace=True, drop=True)

print('Number of Neighbourhoods in South West Borough is ', len(edm_swest['Neighbourhood Name'].unique()))

edm_swest['Neighbourhood Name'].unique()
# Out:
# Number of Neighbourhoods in South West Borough is  73
# array(['RUTHERFORD', 'CHAPPELLE AREA', 'WINDERMERE AREA', 'ALLARD',
#        'GARNEAU', 'TWIN BROOKS', 'HENDERSON ESTATES', 'BLUE QUILL',
#        'BLACKBURNE', 'STEINHAUER', 'RIVER VALLEY OLESKIW',
#        'ASPEN GARDENS', 'GRANDVIEW HEIGHTS', 'ANTHONY HENDAY SOUTH',
#        'RHATIGAN RIDGE', 'ANTHONY HENDAY TERWILLEGAR',
#        'BLACKMUD CREEK RAVINE', 'WESTBROOK ESTATES', 'DUGGAN',
#        'MAGRATH HEIGHTS', 'LANSDOWNE', 'BEARSPAW', 'HODGSON',
#        'OGILVIE RIDGE', 'MACTAGGART', 'WINDERMERE', 'KESWICK AREA',
#        'WHITEMUD CREEK RAVINE NORTH', 'FALCONER HEIGHTS', 'GREENFIELD',
#        'EDGEMONT', 'CARTER CREST', 'EMPIRE PARK', 'SWEET GRASS',
#        'CALLINGWOOD SOUTH', 'BULYEA HEIGHTS',
#        'RIVER VALLEY FORT EDMONTON', 'BLACKMUD CREEK', 'LEGER',
#        'RIVER VALLEY LESSARD NORTH', 'MALMO PLAINS', 'CALLINGWOOD NORTH',
#        'WHITEMUD CREEK RAVINE TWIN BROOKS', 'CAVANAGH',
#        'RIVER VALLEY TERWILLEGAR', 'PLEASANTVIEW', 'HERITAGE VALLEY AREA',
#        'HADDOW', 'SOUTH TERWILLEGAR', 'SKYRATTLER', 'MACEWAN', 'KEHEEWIN',
#        'RICHFORD', 'BRANDER GARDENS', 'TERWILLEGAR TOWNE',
#        'LENDRUM PLACE', 'RIDEAU PARK', 'HERITAGE VALLEY TOWN CENTRE AREA',
#        'BLUE QUILL ESTATES', 'ORMSBY PLACE', 'GRAYDON HILL', 'CALLAGHAN',
#        'BROOKSIDE', 'AMBLESIDE', 'PAISLEY', 'WHITEMUD CREEK RAVINE SOUTH',
#        'RIVER VALLEY WINDERMERE', 'ANTHONY HENDAY SOUTH WEST',
#        'HAYS RIDGE AREA', 'RAMSAY HEIGHTS', 'ROYAL GARDENS', 'ERMINESKIN',
#        'RIVER VALLEY CAMERON'], dtype=object)

# %%
edm_swest
# Out:
#     Neighbourhood Number  ...                                   Location
# 0                   5454  ...   (53.416764847830855, -113.5297880243958)
# 1                   5462  ...    (53.40291668024122, -113.5868447039775)
# 2                   5575  ...   (53.40301453182545, -113.63179590032422)
# 3                   5458  ...  (53.401173930960695, -113.52664141392435)
# 4                   5200  ...  (53.519910825465416, -113.51353555959162)
# ..                   ...  ...                                        ...
# 68                  5465  ...  (53.417622233685385, -113.57770281907861)
# 69                  5340  ...  (53.483367623497735, -113.57903399166699)
# 70                  5430  ...   (53.47941921545243, -113.52805526236676)
# 71                  5180  ...   (53.45763949074272, -113.50572830551565)
# 72                  4467  ...   (53.47235679378515, -113.61607674195818)
#
# [73 rows x 20 columns]

# %% [markdown]
# #### There are 73 neighbourhoods in total in South West Edmonton

# %% [markdown]
# ### Top 5 High Income Neighbourhoods in South West Edmonton

# %% [markdown]
# Let's find the top5 neighborhoods in South West Edmonton by High income population. The top 5 high income neighbourhoods in South West include Rutherford, Twin Brooks, Windermere, Haddow and Terwillegar Towne.

# %%
edm_swest.sort_values(by=['High Income'], ascending=False).head()
# Out:
#     Neighbourhood Number  ...                                   Location
# 0                   5454  ...   (53.416764847830855, -113.5297880243958)
# 5                   5511  ...  (53.444688598308645, -113.53149747692723)
# 25                  5570  ...   (53.43256309588482, -113.62600779671197)
# 47                  5610  ...   (53.45474982252182, -113.59648877700798)
# 54                  5640  ...    (53.45067025466003, -113.5777384340015)
#
# [5 rows x 20 columns]

# %% [markdown]
# ###Plotting a map of South West Edmonton with neighbourhoods and high income population superimposed on it

# %%
edm_sw_map = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood , high in zip(edm_swest['Latitude'], edm_swest['Longitude'], edm_swest['Borough'], edm_swest['Neighbourhood Name'], edm_swest['High Income']):
    label = '{}, {}'.format(neighborhood, high)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(edm_sw_map)  
    
edm_sw_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_0bed1d38fe29435d8d18d15f0ac8e534%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_0bed1d38fe29435d8d18d15f0ac8e534%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_0bed1d38fe29435d8d18d15f0ac8e534%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_0bed1d38fe29435d8d18d15f0ac8e534%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B53.535411%2C%20-113.507996%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_f1157de64b0a446f9b6641cca6476774%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20%2 ...

# %% [markdown]
# ### Using Four Square API to explore the neighbourhood venues and to apply machine learning algorithm to cluster the neighbourhoods and present the findings by plotting it on maps using Folium.

# %%
#Define Foursquare Credentials and Version
CLIENT_ID = '5SWZONRIDCCK0QHZDAM2LSE220YI43EYY3FIBSO4SOPM54WP' # your Foursquare ID
CLIENT_SECRET = '2OJPPSPD315KHGLSRPSDU1E5AMO2SO0Z1FSZHWHOLBD4Y2GV' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 5SWZONRIDCCK0QHZDAM2LSE220YI43EYY3FIBSO4SOPM54WP
# CLIENT_SECRET:2OJPPSPD315KHGLSRPSDU1E5AMO2SO0Z1FSZHWHOLBD4Y2GV

# %% [markdown]
# Defining a function to fetch top 10 venues around a given neighborhood

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighbourhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# Generating Venues

# %%
edm_sw_venues = getNearbyVenues(names=edm_swest['Neighbourhood Name'], latitudes=edm_swest['Latitude'], longitudes=edm_swest['Longitude'] )
# Out:
# RUTHERFORD
# CHAPPELLE AREA
# WINDERMERE AREA
# ALLARD
# GARNEAU
# TWIN BROOKS
# HENDERSON ESTATES
# BLUE QUILL
# BLACKBURNE
# STEINHAUER
# RIVER VALLEY OLESKIW
# ASPEN GARDENS
# GRANDVIEW HEIGHTS
# ANTHONY HENDAY SOUTH
# RHATIGAN RIDGE
# ANTHONY HENDAY TERWILLEGAR
# BLACKMUD CREEK RAVINE
# WESTBROOK ESTATES
# DUGGAN
# MAGRATH HEIGHTS
# LANSDOWNE
# BEARSPAW
# HODGSON
# OGILVIE RIDGE
# MACTAGGART
# WINDERMERE
# KESWICK AREA
# WHITEMUD CREEK RAVINE NORTH
# FALCONER HEIGHTS
# GREENFIELD
# EDGEMONT
# CARTER CREST
# EMPIRE PARK
# SWEET GRASS
# CALLINGWOOD SOUTH
# BULYEA HEIGHTS
# RIVER VALLEY FORT EDMONTON
# BLACKMUD CREEK
# LEGER
# RIVER VALLEY LESSARD NORTH
# MALMO PLAINS
# CALLINGWOOD NORTH
# WHITEMUD CREEK RAVINE TWIN BROOKS
# CAVANAGH
# RIVER VALLEY TERWILLEGAR
# PLEASANTVIEW
# HERITAGE VALLEY AREA
# HADDOW
# SOUTH TERWILLEGAR
# SKYRATTLER
# MACEWAN
# KEHEEWIN
# RICHFORD
# BRANDER GARDENS
# TERWILLEGAR TOWNE
# LENDRUM PLACE
# RIDEAU PARK
# HERITAGE VALLEY TOWN CENTRE AREA
# BLUE QUILL ESTATES
# ORMSBY PLACE
# GRAYDON HILL
# CALLAGHAN
# BROOKSIDE
# AMBLESIDE
# PAISLEY
# WHITEMUD CREEK RAVINE SOUTH
# RIVER VALLEY WINDERMERE
# ANTHONY HENDAY SOUTH WEST
# HAYS RIDGE AREA
# RAMSAY HEIGHTS
# ROYAL GARDENS
# ERMINESKIN
# RIVER VALLEY CAMERON

# %% [markdown]
# Checking out the dataframe containing venue details for neighbourhoods in South West Borough

# %% [markdown]
# There are a total of 276 venues in Southwest Edmonton

# %%
print(edm_sw_venues.shape)
edm_sw_venues.head()
# Out:
# (276, 5)
#     Neighbourhood  ...     Venue Category
# 0      RUTHERFORD  ...  Convenience Store
# 1      RUTHERFORD  ...  Convenience Store
# 2  CHAPPELLE AREA  ...   Insurance Office
# 3  CHAPPELLE AREA  ...        Golf Course
# 4          ALLARD  ...         Restaurant
#
# [5 rows x 5 columns]

# %% [markdown]
# Finding the number of venues in each neighbourhood

# %%
sw_venues =edm_sw_venues.groupby('Neighbourhood').count().drop(['Neighborhood Latitude','Neighborhood Longitude','Venue Category'], axis = 1)
sw_venues.sort_values(by='Venue',ascending=False)
sw_venues
# Out:
#                              Venue
# Neighbourhood
# ALLARD                           5
# AMBLESIDE                        4
# BEARSPAW                         3
# BLACKBURNE                       4
# BLACKMUD CREEK                   3
# ...                            ...
# TWIN BROOKS                      5
# WESTBROOK ESTATES                1
# WHITEMUD CREEK RAVINE NORTH      3
# WHITEMUD CREEK RAVINE SOUTH      1
# WINDERMERE                       3
#
# [63 rows x 1 columns]

# %%
print('There are {} uniques categories.'.format(len(edm_sw_venues['Venue Category'].unique())))
# Out:
# There are 107 uniques categories.

# %% [markdown]
# ###Modelling<a name="mdl"></a>

# %% [markdown]
# One Hot Encoding to Analyze Each Neighborhood

# %%
# one hot encoding
edm_onehot = pd.get_dummies(edm_sw_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
edm_onehot['Neighbourhood'] = edm_sw_venues['Neighbourhood'] 

# move neighborhood column to the first column
fixed_columns = [edm_onehot.columns[-1]] + list(edm_onehot.columns[:-1])
edm_onehot = edm_onehot[fixed_columns]

edm_onehot.head()
# Out:
#     Neighbourhood  Adult Boutique  ...  Wine Shop  Yoga Studio
# 0      RUTHERFORD               0  ...          0            0
# 1      RUTHERFORD               0  ...          0            0
# 2  CHAPPELLE AREA               0  ...          0            0
# 3  CHAPPELLE AREA               0  ...          0            0
# 4          ALLARD               0  ...          0            0
#
# [5 rows x 108 columns]

# %%
edm_onehot.shape
# Out:
# (276, 108)

# %%
edm_sw_grouped =edm_onehot.groupby('Neighbourhood').mean().reset_index()
edm_sw_grouped
# Out:
#                   Neighbourhood  Adult Boutique  ...  Wine Shop  Yoga Studio
# 0                        ALLARD        0.000000  ...        0.0          0.0
# 1                     AMBLESIDE        0.000000  ...        0.0          0.0
# 2                      BEARSPAW        0.000000  ...        0.0          0.0
# 3                    BLACKBURNE        0.000000  ...        0.0          0.0
# 4                BLACKMUD CREEK        0.000000  ...        0.0          0.0
# ..                          ...             ...  ...        ...          ...
# 58                  TWIN BROOKS        0.000000  ...        0.0          0.0
# 59            WESTBROOK ESTATES        0.000000  ...        0.0          0.0
# 60  WHITEMUD CREEK RAVINE NORTH        0.000000  ...        0.0          0.0
# 61  WHITEMUD CREEK RAVINE SOUTH        0.000000  ...        0.0          0.0
# 62                   WINDERMERE        0.333333  ...        0.0          0.0
#
# [63 rows x 108 columns]

# %%
edm_sw_grouped.shape
# Out:
# (62, 105)

# %% [markdown]
# ####Top 5 most common venues across neighborhoods

# %%
num_top_venues = 5

for hood in edm_sw_grouped['Neighbourhood']:
    print("----"+hood+"----")
    temp = edm_sw_grouped[edm_sw_grouped['Neighbourhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----ALLARD----
#                         venue  freq
# 0  Construction & Landscaping   0.4
# 1              Massage Studio   0.2
# 2                 Pizza Place   0.2
# 3                  Restaurant   0.2
# 4              Adult Boutique   0.0
#
#
# ----AMBLESIDE----
#              venue  freq
# 0        Gastropub  0.25
# 1  Thai Restaurant  0.25
# 2      Coffee Shop  0.25
# 3    Grocery Store  0.25
# 4   Adult Boutique  0.00
#
#
# ----BEARSPAW----
#                            venue  freq
# 0          Outdoors & Recreation  0.33
# 1            Rental Car Location  0.33
# 2                           Lake  0.33
# 3  Paper / Office Supplies Store  0.00
# 4                         Resort  0.00
#
#
# ----BLACKBURNE----
#                         venue  freq
# 0  Construction & Landscaping  0.50
# 1                  Playground  0.25
# 2                   Gift Shop  0.25
# 3              Adult Boutique  0.00
# 4                        Park  0.00
#
#
# ----BLACKMUD CREEK----
#             venue  freq
# 0     Post Office  0.33
# 1     Coffee Shop  0.33
# 2   Grocery Store  0.33
# 3  Adult Boutique  0.00
# 4            Park  0.00
#
#
# ----BLACKMUD CREEK RAVINE----
#                            venue  freq
# 0              Electronics Store   0.5
# 1                     Playground   0.5
# 2  Paper / Office Supplies Store   0.0
# 3                      Rest Area   0.0
# 4                         Resort   0.0
#
#
# ----BLUE QUILL----
#                 venue  freq
# 0   Convenience Store  0.29
# 1  Italian Restaurant  0.14
# 2                 Pub  0.14
# 3                 Gym  0.14
# 4  Falafel Restaurant  0.14
#
#
# ----BLUE QUILL ESTATES----
#                     venue  freq
# 0        Business Service  0.50
# 1  Furniture / Home Store  0.25
# 2         Nature Preserve  0.25
# 3          Adult Boutique  0.00
# 4                    Park  0.00
#
#
# ----BRANDER GARDENS----
#                 venue  freq
# 0              School  0.25
# 1         Pizza Place  0.25
# 2                Café  0.25
# 3  Chinese Restaurant  0.25
# 4      Adult Boutique  0.00
#
#
# ----BROOKSIDE----
#                    venue  freq
# 0           Home Service  0.33
# 1           Soccer Field  0.33
# 2                   Park  0.33
# 3         Adult Boutique  0.00
# 4  Outdoors & Recreation  0.00
#
#
# ----BULYEA HEIGHTS----
#             venue  freq
# 0      Baby Store  0.25
# 1     Pizza Place  0.25
# 2            Park  0.25
# 3             Gym  0.25
# 4  Adult Boutique  0.00
#
#
# ----CALLAGHAN----
#                    venue  freq
# 0       Business Service   1.0
# 1         Adult Boutique   0.0
# 2  Outdoors & Recreation   0.0
# 3                 Resort   0.0
# 4    Rental Car Location   0.0
#
#
# ----CALLINGWOOD NORTH----
#                venue  freq
# 0        Pizza Place  0.22
# 1     Sandwich Place  0.11
# 2        IT Services  0.11
# 3       Hockey Arena  0.11
# 4  Convenience Store  0.11
#
#
# ----CALLINGWOOD SOUTH----
#                    venue  freq
# 0   Fast Food Restaurant  0.12
# 1            Coffee Shop  0.12
# 2       Asian Restaurant  0.06
# 3            Gas Station  0.06
# 4  Vietnamese Restaurant  0.06
#
#
# ----CARTER CREST----
#                            venue  freq
# 0                 Scenic Lookout   1.0
# 1                 Adult Boutique   0.0
# 2  Paper / Office Supplies Store   0.0
# 3                         Resort   0.0
# 4            Rental Car Location   0.0
#
#
# ----CAVANAGH----
#                  venue  freq
# 0           Restaurant   1.0
# 1       Adult Boutique   0.0
# 2               Resort   0.0
# 3  Rental Car Location   0.0
# 4                  Pub   0.0
#
#
# ----CHAPPELLE AREA----
#                            venue  freq
# 0               Insurance Office   0.5
# 1                    Golf Course   0.5
# 2                 Adult Boutique   0.0
# 3  Paper / Office Supplies Store   0.0
# 4                         Resort   0.0
#
#
# ----DUGGAN----
#                            venue  freq
# 0                    Candy Store  0.25
# 1               Asian Restaurant  0.25
# 2                            Pub  0.25
# 3             Mexican Restaurant  0.25
# 4  Paper / Office Supplies Store  0.00
#
#
# ----EDGEMONT----
#                         venue  freq
# 0  Construction & Landscaping  0.67
# 1                        Farm  0.33
# 2              Adult Boutique  0.00
# 3                        Park  0.00
# 4                      Resort  0.00
#
#
# ----EMPIRE PARK----
#                        venue  freq
# 0  South American Restaurant  0.12
# 1                Gas Station  0.12
# 2              Shopping Mall  0.12
# 3             Ice Cream Shop  0.12
# 4               Burger Joint  0.12
#
#
# ----ERMINESKIN----
#             venue  freq
# 0     Coffee Shop   0.5
# 1   Grocery Store   0.5
# 2  Adult Boutique   0.0
# 3            Park   0.0
# 4          Resort   0.0
#
#
# ----FALCONER HEIGHTS----
#                   venue  freq
# 0      Asian Restaurant  0.12
# 1  Fast Food Restaurant  0.12
# 2           Pizza Place  0.12
# 3           Coffee Shop  0.12
# 4    Italian Restaurant  0.06
#
#
# ----GARNEAU----
#                   venue  freq
# 0                  Café  0.12
# 1           Pizza Place  0.09
# 2           Coffee Shop  0.09
# 3   Indie Movie Theater  0.06
# 4  Fast Food Restaurant  0.06
#
#
# ----GRAYDON HILL----
#                            venue  freq
# 0                  Garden Center   1.0
# 1                 Adult Boutique   0.0
# 2  Paper / Office Supplies Store   0.0
# 3                         Resort   0.0
# 4            Rental Car Location   0.0
#
#
# ----GREENFIELD----
#                            venue  freq
# 0                         Lounge  0.33
# 1                     Playground  0.33
# 2                  Grocery Store  0.33
# 3                 Adult Boutique  0.00
# 4  Paper / Office Supplies Store  0.00
#
#
# ----HADDOW----
#                  venue  freq
# 0          Yoga Studio  0.33
# 1                  Gym  0.33
# 2                 Park  0.33
# 3               Resort  0.00
# 4  Rental Car Location  0.00
#
#
# ----HAYS RIDGE AREA----
#                            venue  freq
# 0                  Moving Target   1.0
# 1                 Adult Boutique   0.0
# 2  Paper / Office Supplies Store   0.0
# 3                         Resort   0.0
# 4            Rental Car Location   0.0
#
#
# ----HENDERSON ESTATES----
#                    venue  freq
# 0  Performing Arts Venue   0.5
# 1                   Park   0.5
# 2         Adult Boutique   0.0
# 3             Restaurant   0.0
# 4                 Resort   0.0
#
#
# ----HODGSON----
#             venue  freq
# 0      Restaurant  0.12
# 1  Massage Studio  0.12
# 2  Discount Store  0.12
# 3             Gym  0.12
# 4  Ice Cream Shop  0.12
#
#
# ----KEHEEWIN----
#                   venue  freq
# 0        Sandwich Place  0.25
# 1  Fast Food Restaurant  0.25
# 2              Tea Room  0.25
# 3          Neighborhood  0.25
# 4        Adult Boutique  0.00
#
#
# ----KESWICK AREA----
#                            venue  freq
# 0     Construction & Landscaping   1.0
# 1                 Adult Boutique   0.0
# 2  Paper / Office Supplies Store   0.0
# 3                         Resort   0.0
# 4            Rental Car Location   0.0
#
#
# ----LANSDOWNE----
#                     venue  freq
# 0             Yoga Studio  0.14
# 1  Furniture / Home Store  0.14
# 2             Gas Station  0.14
# 3              Playground  0.14
# 4             Bus Station  0.14
#
#
# ----LEGER----
#             venue  freq
# 0  Farmers Market   0.2
# 1  Ice Cream Shop   0.2
# 2     Bus Station   0.2
# 3     Coffee Shop   0.2
# 4             Gym   0.2
#
#
# ----LENDRUM PLACE----
#                  venue  freq
# 0  Japanese Restaurant  0.12
# 1       Sandwich Place  0.12
# 2          Pizza Place  0.12
# 3       Shopping Plaza  0.12
# 4          Gas Station  0.12
#
#
# ----MACEWAN----
#                            venue  freq
# 0                   Liquor Store  0.33
# 1                     Playground  0.33
# 2              Convenience Store  0.33
# 3                 Adult Boutique  0.00
# 4  Paper / Office Supplies Store  0.00
#
#
# ----MACTAGGART----
#                            venue  freq
# 0               Asian Restaurant   0.5
# 1                      BBQ Joint   0.5
# 2                 Adult Boutique   0.0
# 3  Paper / Office Supplies Store   0.0
# 4                      Rest Area   0.0
#
#
# ----MAGRATH HEIGHTS----
#                            venue  freq
# 0           Fast Food Restaurant   1.0
# 1                 Adult Boutique   0.0
# 2  Paper / Office Supplies Store   0.0
# 3                         Resort   0.0
# 4            Rental Car Location   0.0
#
#
# ----MALMO PLAINS----
#                venue  freq
# 0  Electronics Store  0.25
# 1               Lake  0.25
# 2          Juice Bar  0.25
# 3        Fabric Shop  0.25
# 4       Liquor Store  0.00
#
#
# ----OGILVIE RIDGE----
#                         venue  freq
# 0              Scenic Lookout   0.5
# 1  Construction & Landscaping   0.5
# 2              Adult Boutique   0.0
# 3                  Restaurant   0.0
# 4                      Resort   0.0
#
#
# ----ORMSBY PLACE----
#                venue  freq
# 0         Playground   0.2
# 1        Gas Station   0.2
# 2  Mobile Phone Shop   0.2
# 3       Home Service   0.2
# 4  Convenience Store   0.2
#
#
# ----PAISLEY----
#               venue  freq
# 0       Yoga Studio  0.33
# 1       Dry Cleaner  0.33
# 2  Business Service  0.33
# 3              Park  0.00
# 4         Rest Area  0.00
#
#
# ----PLEASANTVIEW----
#                            venue  freq
# 0                           Park   0.5
# 1  Paper / Office Supplies Store   0.5
# 2                 Adult Boutique   0.0
# 3                     Restaurant   0.0
# 4                         Resort   0.0
#
#
# ----RAMSAY HEIGHTS----
#                venue  freq
# 0               Park   0.4
# 1         Skate Park   0.2
# 2  Convenience Store   0.2
# 3        Cheese Shop   0.2
# 4         Restaurant   0.0
#
#
# ----RICHFORD----
#                    venue  freq
# 0                Stadium   0.5
# 1            Gas Station   0.5
# 2  Outdoors & Recreation   0.0
# 3    Rental Car Location   0.0
# 4                    Pub   0.0
#
#
# ----RIDEAU PARK----
#                      venue  freq
# 0             Burger Joint   0.1
# 1                      Pub   0.1
# 2       Mexican Restaurant   0.1
# 3  Health & Beauty Service   0.1
# 4               Board Shop   0.1
#
#
# ----RIVER VALLEY CAMERON----
#                    venue  freq
# 0         Airport Lounge   1.0
# 1  Outdoors & Recreation   0.0
# 2                 Resort   0.0
# 3    Rental Car Location   0.0
# 4                    Pub   0.0
#
#
# ----RIVER VALLEY FORT EDMONTON----
#             venue  freq
# 0      Theme Park  0.25
# 1         Theater  0.25
# 2           Hotel  0.25
# 3   Historic Site  0.25
# 4  Adult Boutique  0.00
#
#
# ----RIVER VALLEY LESSARD NORTH----
#             venue  freq
# 0  Ice Cream Shop  0.17
# 1         Theater  0.17
# 2           Hotel  0.17
# 3       Gift Shop  0.17
# 4            Café  0.17
#
#
# ----RIVER VALLEY OLESKIW----
#                    venue  freq
# 0                  Trail   0.5
# 1            Golf Course   0.5
# 2         Adult Boutique   0.0
# 3  Outdoors & Recreation   0.0
# 4    Rental Car Location   0.0
#
#
# ----RIVER VALLEY TERWILLEGAR----
#                            venue  freq
# 0                        Dog Run   1.0
# 1                 Adult Boutique   0.0
# 2  Paper / Office Supplies Store   0.0
# 3                         Resort   0.0
# 4            Rental Car Location   0.0
#
#
# ----RIVER VALLEY WINDERMERE----
#                     venue  freq
# 0  Furniture / Home Store  0.33
# 1             Golf Course  0.33
# 2          Clothing Store  0.33
# 3          Adult Boutique  0.00
# 4              Restaurant  0.00
#
#
# ----ROYAL GARDENS----
#            venue  freq
# 0  Grocery Store   0.2
# 1   Liquor Store   0.2
# 2         Lounge   0.2
# 3   Home Service   0.2
# 4   Tennis Court   0.2
#
#
# ----RUTHERFORD----
#                            venue  freq
# 0              Convenience Store   1.0
# 1                 Adult Boutique   0.0
# 2  Paper / Office Supplies Store   0.0
# 3                         Resort   0.0
# 4            Rental Car Location   0.0
#
#
# ----SKYRATTLER----
#                            venue  freq
# 0             Italian Restaurant  0.25
# 1                     Shoe Store  0.25
# 2                            Pub  0.25
# 3                    Pizza Place  0.25
# 4  Paper / Office Supplies Store  0.00
#
#
# ----SOUTH TERWILLEGAR----
#                    venue  freq
# 0            IT Services   0.5
# 1                   Park   0.5
# 2         Adult Boutique   0.0
# 3  Outdoors & Recreation   0.0
# 4                 Resort   0.0
#
#
# ----STEINHAUER----
#             venue  freq
# 0             Pub  0.33
# 1     Pizza Place  0.33
# 2            Park  0.33
# 3  Adult Boutique  0.00
# 4      Restaurant  0.00
#
#
# ----SWEET GRASS----
#                 venue  freq
# 0   Convenience Store   0.4
# 1         Yoga Studio   0.2
# 2                 Gym   0.2
# 3  Falafel Restaurant   0.2
# 4        Liquor Store   0.0
#
#
# ----TERWILLEGAR TOWNE----
#                            venue  freq
# 0                  Shopping Mall   0.5
# 1                     Playground   0.5
# 2                 Adult Boutique   0.0
# 3  Paper / Office Supplies Store   0.0
# 4                         Resort   0.0
#
#
# ----TWIN BROOKS----
#               venue  freq
# 0    Sandwich Place   0.2
# 1            Bakery   0.2
# 2        Playground   0.2
# 3  Department Store   0.2
# 4      Home Service   0.2
#
#
# ----WESTBROOK ESTATES----
#                  venue  freq
# 0               Resort   1.0
# 1       Adult Boutique   0.0
# 2           Restaurant   0.0
# 3  Rental Car Location   0.0
# 4                  Pub   0.0
#
#
# ----WHITEMUD CREEK RAVINE NORTH----
#                            venue  freq
# 0                      Rest Area  0.33
# 1                     Ski Chalet  0.33
# 2                     Campground  0.33
# 3  Paper / Office Supplies Store  0.00
# 4                         Resort  0.00
#
#
# ----WHITEMUD CREEK RAVINE SOUTH----
#                    venue  freq
# 0           Home Service   1.0
# 1         Adult Boutique   0.0
# 2  Outdoors & Recreation   0.0
# 3                 Resort   0.0
# 4    Rental Car Location   0.0
#
#
# ----WINDERMERE----
#                    venue  freq
# 0           Home Service  0.67
# 1         Adult Boutique  0.33
# 2  Outdoors & Recreation  0.00
# 3                 Resort  0.00
# 4    Rental Car Location  0.00

# %% [markdown]
# Now let's create the new dataframe and display the top 10 venues for each neighborhood.

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighbourhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighbourhood'] = edm_sw_grouped['Neighbourhood']

for ind in np.arange(edm_sw_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(edm_sw_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted
# Out:
#                   Neighbourhood  ...  10th Most Common Venue
# 0                        ALLARD  ...    Fast Food Restaurant
# 1                     AMBLESIDE  ...    Fast Food Restaurant
# 2                      BEARSPAW  ...  Furniture / Home Store
# 3                    BLACKBURNE  ...  Furniture / Home Store
# 4                BLACKMUD CREEK  ...           Garden Center
# ..                          ...  ...                     ...
# 58                  TWIN BROOKS  ...          Farmers Market
# 59            WESTBROOK ESTATES  ...           Garden Center
# 60  WHITEMUD CREEK RAVINE NORTH  ...          Farmers Market
# 61  WHITEMUD CREEK RAVINE SOUTH  ...           Garden Center
# 62                   WINDERMERE  ...           Garden Center
#
# [63 rows x 11 columns]

# %% [markdown]
# ## Cluster Neighbourhoods

# %%
# set number of clusters
kclusters = 5

edm_grouped_clustering = edm_sw_grouped.drop('Neighbourhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(edm_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([3, 2, 2, 3, 2, 0, 0, 2, 2, 1], dtype=int32)

# %%
# add clustering labels
#neighborhoods_venues_sorted.drop(['Cluster Labels'], axis=1, inplace=True)
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

edm_merged = edm_swest

#neighborhoods_venues_sorted.head()
edm_merged.rename(columns = {'Neighbourhood Name':'Neighbourhood'}, inplace = True)
edm_merged = edm_merged.join(neighborhoods_venues_sorted.set_index('Neighbourhood'), on='Neighbourhood')
#edm_merged.drop(['  Location'])
edm_merged.dropna(inplace=True)
edm_merged.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#    Neighbourhood Number  ... 10th Most Common Venue
# 0                  5454  ...          Garden Center
# 1                  5462  ...          Garden Center
# 3                  5458  ...   Fast Food Restaurant
# 4                  5200  ...    Japanese Restaurant
# 5                  5511  ...         Farmers Market
#
# [5 rows x 31 columns]

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(edm_merged['Latitude'], edm_merged['Longitude'], edm_merged['Neighbourhood'],edm_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        
        color=rainbow[int(cluster)-1],
        fill=True,
        fill_color=rainbow[int(cluster)-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_cca4e7080bba4386bf61efc9f453840a%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_cca4e7080bba4386bf61efc9f453840a%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_cca4e7080bba4386bf61efc9f453840a%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_cca4e7080bba4386bf61efc9f453840a%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B53.535411%2C%20-113.507996%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_c52a6eff84f941df947a2ab92c94160f%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20%2 ...

# %% [markdown]
# ##Examining Clusters

# %% [markdown]
# ### Cluster 1 - Cluster with most neighbourhoods having convenience stores, play grounds and yoga studios as their most common venues

# %%
edm_merged.loc[edm_merged['Cluster Labels'] == 0, edm_merged.columns[[1] + list(range(5, edm_merged.shape[1]))]]
# Out:
#             Neighbourhood  ...  10th Most Common Venue
# 0              RUTHERFORD  ...           Garden Center
# 5             TWIN BROOKS  ...          Farmers Market
# 7              BLUE QUILL  ...       Electronics Store
# 16  BLACKMUD CREEK RAVINE  ...           Garden Center
# 29             GREENFIELD  ...  Furniture / Home Store
# 33            SWEET GRASS  ...  Furniture / Home Store
# 50                MACEWAN  ...  Furniture / Home Store
# 54      TERWILLEGAR TOWNE  ...  Furniture / Home Store
# 59           ORMSBY PLACE  ...          Farmers Market
#
# [9 rows x 27 columns]

# %% [markdown]
# ### Cluster 2 - Another large cluster with good number of parks in most neighbourhoods

# %%
edm_merged.loc[edm_merged['Cluster Labels'] == 1, edm_merged.columns[[1] + list(range(5, edm_merged.shape[1]))]]
# Out:
#         Neighbourhood  ...  10th Most Common Venue
# 6   HENDERSON ESTATES  ...  Furniture / Home Store
# 9          STEINHAUER  ...  Furniture / Home Store
# 35     BULYEA HEIGHTS  ...    Fast Food Restaurant
# 45       PLEASANTVIEW  ...  Furniture / Home Store
# 47             HADDOW  ...  Furniture / Home Store
# 48  SOUTH TERWILLEGAR  ...  Furniture / Home Store
# 62          BROOKSIDE  ...    Fast Food Restaurant
# 69     RAMSAY HEIGHTS  ...    Fast Food Restaurant
#
# [8 rows x 27 columns]

# %% [markdown]
# ### Cluster 3 - This is the biggest cluster with a large number of food joints

# %%
edm_merged.loc[edm_merged['Cluster Labels'] == 2, edm_merged.columns[[1] + list(range(5, edm_merged.shape[1]))]]
# Out:
#                   Neighbourhood  ...  10th Most Common Venue
# 1                CHAPPELLE AREA  ...           Garden Center
# 4                       GARNEAU  ...     Japanese Restaurant
# 10         RIVER VALLEY OLESKIW  ...  Furniture / Home Store
# 17            WESTBROOK ESTATES  ...           Garden Center
# 18                       DUGGAN  ...  Furniture / Home Store
# 19              MAGRATH HEIGHTS  ...             Gas Station
# 20                    LANSDOWNE  ...          Farmers Market
# 21                     BEARSPAW  ...  Furniture / Home Store
# 22                      HODGSON  ...      Falafel Restaurant
# 24                   MACTAGGART  ...           Garden Center
# 27  WHITEMUD CREEK RAVINE NORTH  ...          Farmers Market
# 28             FALCONER HEIGHTS  ...          Sandwich Place
# 31                 CARTER CREST  ...           Garden Center
# 32                  EMPIRE PARK  ...               Gastropub
# 34            CALLINGWOOD SOUTH  ...   Vietnamese Restaurant
# 36   RIVER VALLEY FORT EDMONTON  ...                    Farm
# 37               BLACKMUD CREEK  ...           Garden Center
# 38                        LEGER  ...  Furniture / Home Store
# 39   RIVER VALLEY LESSARD NORTH  ...          Farmers Market
# 40                 MALMO PLAINS  ...  Furniture / Home Store
# 41            CALLINGWOOD NORTH  ...             Fabric Shop
# 43                     CAVANAGH  ...           Garden Center
# 44     RIVER VALLEY TERWILLEGAR  ...             Gas Station
# 49                   SKYRATTLER  ...    Fast Food Restaurant
# 51                     KEHEEWIN  ...          Farmers Market
# 52                     RICHFORD  ...  Furniture / Home Store
# 53              BRANDER GARDENS  ...    Fast Food Restaurant
# 55                LENDRUM PLACE  ...             Fabric Shop
# 56                  RIDEAU PARK  ...            Burger Joint
# 58           BLUE QUILL ESTATES  ...             Gas Station
# 60                 GRAYDON HILL  ...             Gas Station
# 61                    CALLAGHAN  ...           Garden Center
# 63                    AMBLESIDE  ...    Fast Food Restaurant
# 64                      PAISLEY  ...  Furniture / Home Store
# 66      RIVER VALLEY WINDERMERE  ...           Garden Center
# 68              HAYS RIDGE AREA  ...           Garden Center
# 70                ROYAL GARDENS  ...                    Farm
# 71                   ERMINESKIN  ...           Garden Center
# 72         RIVER VALLEY CAMERON  ...           Garden Center
#
# [39 rows x 27 columns]

# %% [markdown]
# ### Cluster 4 - Smaller cluster with most neighbourhoods having construction and landscaping business as their most common venue

# %%
edm_merged.loc[edm_merged['Cluster Labels'] == 3, edm_merged.columns[[1] + list(range(5, edm_merged.shape[1]))]]
# Out:
#     Neighbourhood  ...  10th Most Common Venue
# 3          ALLARD  ...    Fast Food Restaurant
# 8      BLACKBURNE  ...  Furniture / Home Store
# 23  OGILVIE RIDGE  ...  Furniture / Home Store
# 26   KESWICK AREA  ...           Garden Center
# 30       EDGEMONT  ...           Garden Center
#
# [5 rows x 27 columns]

# %% [markdown]
# ###Cluster 5 - Smallest cluster with only two neighbourhoods. They both have home service as their most common venue. Whitemud creek ravine seems to be an outlier.

# %%
edm_merged.loc[edm_merged['Cluster Labels'] == 4, edm_merged.columns[[1] + list(range(5, edm_merged.shape[1]))]]
# Out:
#                   Neighbourhood  ...  10th Most Common Venue
# 25                   WINDERMERE  ...           Garden Center
# 65  WHITEMUD CREEK RAVINE SOUTH  ...           Garden Center
#
# [2 rows x 27 columns]

# %% [markdown]
# ### Observations
#
# 1 South West Edmonton has the largest population of affluent class population and can be chosen to start any luxury business.
#
# 2.Central zone is not ideal for starting a luxury business.
#
# 3.Cluster 2 has a large number of yoga studios and gyms.
#
# 4.Neighbourhoods in cluster 4 seems to be saturated with construction and landscaping business and are not ideal locations for such categories of business.
#
# 5.Similarly cluster 3 already seems to be saturated with a large number of restaurants and food joints and does not seem to be preferred for anyone wishing to start a restaurant business.

# %% [markdown]
# ### Results and Discussion
# The objective of the business problem was to help new entrepreneurs identify the most affluent borough in Edmonton for starting a luxury business. This has been achieved by making use of Edmonton's census and income data to identify an affluent borough with large number of high income population for a luxury business to prosper. After selecting the borough we  studied the neighbourhoods in this borough to identify the common business categories already present. We achieved this by grouping the neighborhoods into clusters using k means algorithm and identifying commonalities within each cluster.

# %% [markdown]
# ###Conclusion
# We have explored the census and income data of Edmonton to understand the neighbourhood of Edmonton and later categorized them into different borough. On analyzing , it has been found that South West Edmonton is the most affluent borough in Edmonton and is the most favourable location for any new entrepreneur who wishes to start a luxury business.
